# %%
data = "Pakistan zinda bad"

print (data)
# Out:
# Pakistan zinda bad

# %%
data = "Pakistan zinda bad"

print (data)

print(type(data))
# Out:
# Pakistan zinda bad
# <class 'str'>

# %% [markdown]
# convert special character into nornal **character**
# * place "**\**" before any special character

# %%
data= 'Pakistan zinda bad \' 123 ! "hello world'

print(data)

print(type(data))
# Out:
# Pakistan zinda bad ' 123 ! "hello world
# <class 'str'>

# %% [markdown]
# assign multiline string

# %%
abc = "line1 Pakistan"\
"line2 Pakistan"\
"line3 Pakistan"

print(abc)

print(type(abc))
# Out:
# line1 Pakistanline2 Pakistanline3 Pakistan
# <class 'str'>

# %%
abc =""""
line1 Hello world
line2 Pakistan zinda bad
line3 we love our country
"""
abc
# Out:
# '"\nline1 Hello world\nline2 Pakistan zinda bad\nline3 we love our country\n'

# %%
abc =""""
line1 Hello world
line2 Pakistan zinda bad
line3 we love our country
"""
print(abc)
# Out:
# "
# line1 Hello world
# line2 Pakistan zinda bad
# line3 we love our country

# %% [markdown]
# #Concatination and text formation

# %%
"1" + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-ec358fc6499a> in <cell line: 1>()
# ----> 1 "1" + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
"1" + "1"
# Out:
# '11'

# %%
1 + 1
# Out:
# 2

# %%
a= input("Enter no1;")
b= input("Enter no2")

print(type(a), type(b))
print(a+b)
# Out:
# Enter no1;2
# Enter no23
# <class 'str'> <class 'str'>
# 23

# %% [markdown]
# type casting

# %%
a="7"
print("a",a,type(a))
a= int(a) #convert string into integer
print("a",a,type(a))
a= float(a) #convert string into float
print("a",a,type(a))
# Out:
# a 7 <class 'str'>
# a 7 <class 'int'>
# a 7.0 <class 'float'>

# %%
a= input("Enter no1:")
b= input("Enter no2:")

print(type(a), type(b))
print(a+b)
# Out:
# Enter no1:3
# Enter no2:4
# <class 'str'> <class 'str'>
# 34

# %%
a= int(input("Enter no1:"))
b= int(input("Enter no2:"))

print(type(a), type(b))
print(a+b)
# Out:
# Enter no1:3
# Enter no2:5
# <class 'int'> <class 'int'>
# 8

# %%
name= "raniya khan"
roll_no= 500
fname= "raees ahmed"
contact_no= "03012979376"

card = "Ned university \nstudent roll no:" + str(roll_no)+\
"\nStudent name:" + name +\
"\nfather name:" + fname+\
"\ncontact no:" + contact_no

print(card)
# Out:
# Ned university
# student roll no:500
# Student name:raniya khan
# father name:raees ahmed
# contact no:03012979376

# %%
card="""Ned university
student roll no:500
Student name:raniya khan
father name:raees ahmed
contact no:03012979376
"""
print(card)
# Out:
# Ned university
# student roll no:500
# Student name:raniya khan
# father name:raees ahmed
# contact no:03012979376

# %%
roll_no= 500
card="""
Ned university
student roll no:{}
Student name:raniya khan
father name:raees ahmed
contact no:03012979376
""".format(roll_no)
print(card)
# Out:
# Ned university
# student roll no:500
# Student name:raniya khan
# father name:raees ahmed
# contact no:03012979376

# %%
roll_no= 500
Name= "raniya khan"
fnmame= "raees ahmed"
contactno= "03012979376"
roll_no= 500
card="""
Ned university
student roll no:{}
Student name:{}
father name:{}
contact no:{}
""".format(roll_no,Name,fname,contactno)
#             0     1     2     3
print(card)
# Out:
# Ned university
# student roll no:500
# Student name:raniya khan
# father name:raees ahmed
# contact no:03012979376

# %%
roll_no= input("roll_no")
Name= input("Name")
fnmame= input("fname:")
contactno= input("contact no:")
card="""
Ned university
student roll no:{}
Student name:{}
father name:{}
contact no:{}
""".format(roll_no,Name,fname,contactno)
#             0     1     2     3
print(card)
# Out:
# roll_no123
# Namedarrer
# fname:raees ahmed
# contact no:0342156
#
# Ned university
# student roll no:123
# Student name:darrer
# father name:raees ahmed
# contact no:0342156

# %% [markdown]
# %s string
# %d number

# %%
roll_no= 500
Name= "raniya khan"
fnmame= "raees ahmed"
contactno= "03012979376"
roll_no= 500
card=f"""
Ned university
student roll no:{roll_no}
Student name:{name}
father name:{fname}
contact no:{contactno}
""".format(roll_no,Name,fname,contactno)
#             0     1     2     3
print(card)
# Out:
# Ned university
# student roll no:500
# Student name:raniya khan
# father name:raees ahmed
# contact no:03012979376
