# %%
a= "Pakistan zinda bad!"

print(type(a))
print(dir(a)) #dir returns all methods and attributes
# Out:
# <class 'str'>
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# All **Methods**/function, **attributes**/properties/fields of string
# *  method_name()
# *  attribute_name
#
# * How we can call methods or attribute
#       * object_name.method_name()
#       * object_name.attribute_name

# %%
txt="""Pakistan zinda bad!
we love our country."""
print(txt.capitalize())
# Out:
# Pakistan zinda bad!
# we love our country.

# %%
txt="""Pakistan zinda bad!
we love our country."""
print(txt.casefold())
# Out:
# pakistan zinda bad!
# we love our country.

# %%
name="Raniya khan"
print(len(name))  #len global function
# Out:
# 11

# %%
name="Raniya khan"
print(name.__len__())   # method
# Out:
# 11

# %%
name="Raniya khan"
name.center(12)
# Out:
# 'Raniya khan '

# %%
name="Raniya khan"
print(name.count("a"))
# Out:
# 3

# %%
name= "Raniya khan is studying AI at Ned"
print(name.count("Raniya"))
# Out:
# 1

# %%
name="Raniya khan"
print(name.count("a")+name.count("r")+name.count("R"))
# Out:
# 4

# %%
name="Raniya khan"   #step1 Raniya khan
name=name.casefold()  #convert into small letters #step2  raniya khan
print(name) #step3 display
#         a=3            r=1
print(name.count("a"))  #count method always return int value
print(name.count("r"))
# Out:
# raniya khan
# 3
# 1

# %% [markdown]
# UTF-8 encode the string:

# %%
txt = "My name is Ståle"

x = txt.encode()

print(x)
# Out:
# b'My name is St\xc3\xa5le'

# %% [markdown]
# These examples uses ascii encoding, and a character that cannot be encoded, showing the result with different errors:

# %%
txt = "My name is Ståle"
       #encoding    #attribute

print(txt.encode(encoding="ascii",errors="backslashreplace"))
print(txt.encode(encoding="ascii",errors="ignore"))
print(txt.encode(encoding="ascii",errors="namereplace"))
print(txt.encode(encoding="ascii",errors="replace"))
print(txt.encode(encoding="ascii",errors="xmlcharrefreplace"))
# Out:
# b'My name is St\\xe5le'
# b'My name is Stle'
# b'My name is St\\N{LATIN SMALL LETTER A WITH RING ABOVE}le'
# b'My name is St?le'
# b'My name is St&#229;le'

# %%
name="Raniya khan"
print(name.endswith("han"))
print(name.endswith("a"))
# Out:
# True
# False

# %%
name="Raniya khan"
print(name.startswith("Ran"))
print(name.startswith("a"))
# Out:
# True
# False

# %%
name="Raniya khan"
search=input("startswith")

print(name.startswith("Ran"))
print(name.startswith("a"))
# Out:
# True
# False

# %%
card = """
Ned Uiversity
Batch: 5
Class:\tpython
Name:\tRaniya Khan
Father's name:\tSyed Raeees 
"""

print(card.expandtabs(10))
# Out:
# Ned Uiversity
# Batch: 5
# Class:    python
# Name:     Raniya Khan
# Father's name:      Syed Raeees

# %%
name = "RaNiya khan"
# ?name.lower()
# Out:
# Signature: name.lower()
# Docstring: Return a copy of the string converted to lowercase.
# Type:      builtin_function_or_method

# %%
name = "RaNiya khan"
name.lower()
# Out:
# 'raniya khan'

# %%
name = "    RaNiya khan   "
name.lstrip()
# Out:
# 'RaNiya khan   '

# %%
name = "     RaNiya khan    "
name.rstrip()
# Out:
# '     RaNiya khan'

# %%
name = "     RaNiya khan    "
name.strip()
# Out:
# 'RaNiya khan'

# %%
name = "Raniya khan"
name.replace("khan", "dareer")
# Out:
# 'Raniya dareer'

# %%
name = "Raniya khan,khan,khan"
name.replace("khan", "dareer")
# Out:
# 'Raniya dareer,dareer,dareer'

# %%
name = "Raniya khan,khan,khan"
name.replace("khan", "dareer",-1)
# Out:
# 'Raniya dareer,dareer,dareer'

# %%
name = "Raniya khan"
name.index("khan")
# Out:
# 7

# %%
name = "Raniya khan"
name.find("khan")
# Out:
# 7

# %%
name = "Raniya khan"
name.count("khan")
# Out:
# 1

# %% [markdown]
# All **methods**/functions,#attributes/properties/fields of strings
